# %% [markdown]
# What are the main characteristics which have the most impact on the car price?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the dataset

# %%
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()       # head prints first five rows of a dataset
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.corr()   # correlation is a statistical technique which shows how strong the items are related with each other
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Question
# Find the correlation between the following columns: bore, stroke,compression-ratio , and horsepower?

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# In order to start understanding the (linear) relationship between an individual variable and the price. We can do this by using "regplot", which plots the scatterplot plus the fitted regression line for the data

# %%
sns.regplot(x="engine-size",y='price',data=df)
plt.show()

# %% [markdown]
# we can observe from the above graph as engines size increases the price also increases , we can observe that the regression line is almost a perfect diaganol, hence we can say has strong relation ship

# %%
sns.regplot(x="highway-mpg",y='price',data = df)
plt.show()

# %% [markdown]
# As the highway-mpg goes up, the price goes down: this indicates an inverse/negative relationship between these two variables. Highway mpg could potentially be a predictor of price.

# %%
sns.regplot(x="peak-rpm",y='price',data=df)
plt.show()

# %% [markdown]
# We can observe that the scatter points are very far from the regression line and regression line is also very close to the horizontal line hence we say the peak rpm is not a good predictor of price

# %% [markdown]
# Questions
# 1)find the correlation between price and stroke, do you expect a linear relation ship between price and stroke? verify your relationship using regplot

# %%
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# we can observe that the correlation ship between the stroke and price is low, hence we predict that their is weak relationship and no linear relationship, lets verify our results by ploting the regplot curve

# %%
sns.regplot(x='stroke',y='price',data=df)
plt.show()

# %% [markdown]
# ###  Boxplots are used to visualize the categorical variables

# %%
sns.boxplot(x='body-style',y='price',data=df)
plt.show()

# %%
sns.boxplot(x='engine-location',y='price',data=df)
plt.show()

# %% [markdown]
# from the above graphs we can see that the boxplot between the body-style and price has lot of overlappings, hence it may be not a good predictor. But the boxplot between the price and engine-location are clearly distributed and we dont have any overlappings hence we can say that it is a good predictor

# %% [markdown]
# ####  Descriptive statistical analaysis

# %%
# describe will give all the statistical calculalations of the data
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
# describe defaultly skips the object type, hence we can also include as follows
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
# the value_counts() counts the count of different categories of in the given columnn
#note that value_count works only on the pandas series, hence we included only one bracket
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
# lets do the process but lets rename the drive-wheels to value_count_wheels
dfw = df['drive-wheels'].value_counts().to_frame()
dfw.rename(columns = {'drive-wheels':'value_count_wheels'},inplace = True)
dfw
# Out:
#      value_count_wheels
# fwd                 118
# rwd                  75
# 4wd                   8

# %%
# we can rename the index name also
print(dfw.index.name)
# Out:
# None

# %%
# since we dont have any name to the index hence we got none
dfw.index.name = 'drive-wheels'
print(dfw.index.name)
# Out:
# drive-wheels

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group=df[['drive-wheels','body-style','price']]
a=df_group.groupby(['drive-wheels','body-style'],as_index=False).mean()
a
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
b=a.pivot(index="drive-wheels",columns='body-style')
b
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
plt.pcolor(b,cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# The heatmap plots the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' in the vertical and horizontal axis respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.

# %%
from scipy import stats
pearson_coeff,p_value=stats.pearsonr(df['engine-size'],df['price'])
p_value   # if p value is lessthan 0.001 then we can say that strongly related
# Out:
# 9.265491622197996e-64
